# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#load database

dataset = pd.read_csv('DiffData_classification_noise.csv')#.dropna()

# print (dataset.head(20)) #head of the data file with 20 rows
# print (dataset.tail(20))
print (dataset.describe().T) #simple statistics like mean, std, percentile

# edit database as needed
# reduce set of importance, rescale values etc...
df = dataset.copy()
df["target"] = [1 if label == "Dgb" else 0 for label in df["Diffusion_type"]]

# setup xdata which is input and y data which is target
#xInput = df.drop(["target"], axis = 1)
xInput = df[["distance","time"]]
yTarget = df[["target"]]

# print(xInput.head(10))
# print(yTarget.head(10))
# Out:
#           count        mean         std       min         25%         50%  \
# time      980.0  300.000000  173.647540  0.000000  149.693252  300.000000
# distance  980.0    0.028601    0.016163 -0.000355    0.015133    0.026372
#
#                  75%         max
# time      450.306748  600.000000
# distance    0.041898    0.064679

# %%
# split data for training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xInput,yTarget, test_size=0.2, random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

from sklearn.svm import SVC
# Create a baseline SVM classifier
baseline_svm = SVC()
baseline_svm.fit(x_train, y_train.values.ravel())
y_pred = baseline_svm.predict(x_test)

from sklearn.metrics import confusion_matrix, accuracy_score,classification_report 
print ("\nConfusion Matrix:\n",confusion_matrix(y_test, y_pred))
print('\n')
print ("accuracy: ",accuracy_score(y_test, y_pred))
print('\n')
print(classification_report(y_test,y_pred))


#get CV score
from sklearn.model_selection import cross_val_score

scores = cross_val_score(baseline_svm, x_train, y_train.values.ravel(), scoring='accuracy', cv=5)
print(scores)
print("Final CV Score: {:5.2f}".format(np.mean(scores)))
# Out:
# Confusion Matrix:
#  [[81 17]
#  [ 0 98]]
#
#
# accuracy:  0.9132653061224489
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        98
#            1       0.85      1.00      0.92        98
#
#     accuracy                           0.91       196
#    macro avg       0.93      0.91      0.91       196
# weighted avg       0.93      0.91      0.91       196
#
# [0.92356688 0.91719745 0.93630573 0.89808917 0.91025641]
# Final CV Score:  0.92

# %%
# split data for training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xInput,yTarget, test_size=0.2, random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

from sklearn.svm import SVC
# Create a baseline SVM classifier
baseline_svm = SVC()
baseline_svm.fit(x_train, y_train.values.ravel())
y_pred = baseline_svm.predict(x_test)

# %%
# hyper parameter tuning # grid
from sklearn.model_selection import GridSearchCV
# define the hyperparameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': [0.1, 1, 'scale', 'auto']
}

# create the GridSearchCV object
grid_search = GridSearchCV(estimator = baseline_svm, param_grid = param_grid, cv = 5, verbose = 1)

# fit the model with the grid of hyperparameters
grid_search.fit(x_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.1, 1, 'scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=1)

# %%
from sklearn.metrics import accuracy_score

# Get the best hyperparameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Evaluate the best model
y_pred_best = best_model.predict(x_test)
accuracy_best = accuracy_score(y_test, y_pred_best)

print(f"Best SVM Accuracy: {accuracy_best:.2f}")
print(f"Best Hyperparameters: {best_params}")
# Out:
# Best SVM Accuracy: 0.93
# Best Hyperparameters: {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.svm import SVC
import numpy as np

# Define the hyperparameter distribution
param_dist = {
    'C': uniform(0.1, 10),  # Uniform distribution between 0.1 and 10
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'] + list(np.logspace(-3, 3, 5))
}

# Create the RandomizedSearchCV object
randomized_search = RandomizedSearchCV(estimator=SVC(), param_distributions=param_dist, n_iter=18, cv=5, verbose=3)

# Fit the model with the randomized grid of hyperparameters
randomized_search.fit(x_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END C=1.4073512554586243, gamma=auto, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 2/5] END C=1.4073512554586243, gamma=auto, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 3/5] END C=1.4073512554586243, gamma=auto, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/5] END C=1.4073512554586243, gamma=auto, kernel=rbf;, score=0.898 total time=   0.0s
# [CV 5/5] END C=1.4073512554586243, gamma=auto, kernel=rbf;, score=0.910 total time=   0.0s
# [CV 1/5] END C=1.5437226368137391, gamma=1000.0, kernel=rbf;, score=0.771 total time=   0.0s
# [CV 2/5] END C=1.5437226368137391, gamma=1000.0, kernel=rbf;, score=0.777 total time=   0.0s
# [CV 3/5] END C=1.5437226368137391, gamma=1000.0, kernel=rbf;, score=0.803 total time=   0.0s
# [CV 4/5] END C=1.5437226368137391, gamma=1000.0, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END C=1.5437226368137391, gamma=1000.0, kernel=rbf;, score=0.776 total time=   0.0s
# [CV 1/5] END C=9.619547082340997, gamma=1.0, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=9.619547082340997, gamma=1.0, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=9.619547082340997, gamma=1.0, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=9.619547082340997, gamma=1.0, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=9.619547082340997, gamma=1.0, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=4.060085041542976, gamma=31.622776601683793, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=4.060085041542976, gamma=31.622776601683793, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=4.060085041542976, gamma=31.622776601683793, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=4.060085041542976, gamma=31.622776601683793, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=4.060085041542976, gamma=31.622776601683793, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=6.762305443978255, gamma=auto, kernel=poly;, score=0.924 total time=   0.0s
# [CV 2/5] END C=6.762305443978255, gamma=auto, kernel=poly;, score=0.904 total time=   0.0s
# [CV 3/5] END C=6.762305443978255, gamma=auto, kernel=poly;, score=0.911 total time=   0.0s
# [CV 4/5] END C=6.762305443978255, gamma=auto, kernel=poly;, score=0.885 total time=   0.0s
# [CV 5/5] END C=6.762305443978255, gamma=auto, kernel=poly;, score=0.904 total time=   0.0s
# [CV 1/5] END C=9.197828818670855, gamma=31.622776601683793, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=9.197828818670855, gamma=31.622776601683793, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=9.197828818670855, gamma=31.622776601683793, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=9.197828818670855, gamma=31.622776601683793, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=9.197828818670855, gamma=31.622776601683793, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=9.783241673750744, gamma=31.622776601683793, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=9.783241673750744, gamma=31.622776601683793, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=9.783241673750744, gamma=31.622776601683793, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=9.783241673750744, gamma=31.622776601683793, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=9.783241673750744, gamma=31.622776601683793, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=8.261187853048744, gamma=scale, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=8.261187853048744, gamma=scale, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=8.261187853048744, gamma=scale, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=8.261187853048744, gamma=scale, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=8.261187853048744, gamma=scale, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=4.614595612356232, gamma=auto, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=4.614595612356232, gamma=auto, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=4.614595612356232, gamma=auto, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=4.614595612356232, gamma=auto, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=4.614595612356232, gamma=auto, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=0.9389174249146724, gamma=1000.0, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=0.9389174249146724, gamma=1000.0, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=0.9389174249146724, gamma=1000.0, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=0.9389174249146724, gamma=1000.0, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=0.9389174249146724, gamma=1000.0, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=2.695563349892356, gamma=scale, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 2/5] END C=2.695563349892356, gamma=scale, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 3/5] END C=2.695563349892356, gamma=scale, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/5] END C=2.695563349892356, gamma=scale, kernel=rbf;, score=0.898 total time=   0.0s
# [CV 5/5] END C=2.695563349892356, gamma=scale, kernel=rbf;, score=0.897 total time=   0.0s
# [CV 1/5] END C=8.890343251253146, gamma=0.03162277660168379, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=8.890343251253146, gamma=0.03162277660168379, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=8.890343251253146, gamma=0.03162277660168379, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=8.890343251253146, gamma=0.03162277660168379, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=8.890343251253146, gamma=0.03162277660168379, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=7.026723081058964, gamma=0.03162277660168379, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=7.026723081058964, gamma=0.03162277660168379, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=7.026723081058964, gamma=0.03162277660168379, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=7.026723081058964, gamma=0.03162277660168379, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=7.026723081058964, gamma=0.03162277660168379, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=6.514452867679059, gamma=0.03162277660168379, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 2/5] END C=6.514452867679059, gamma=0.03162277660168379, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 3/5] END C=6.514452867679059, gamma=0.03162277660168379, kernel=rbf;, score=0.917 total time=   0.0s
# [CV 4/5] END C=6.514452867679059, gamma=0.03162277660168379, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 5/5] END C=6.514452867679059, gamma=0.03162277660168379, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 1/5] END C=3.308766276013816, gamma=0.03162277660168379, kernel=linear;, score=0.917 total time=   0.0s
# [CV 2/5] END C=3.308766276013816, gamma=0.03162277660168379, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=3.308766276013816, gamma=0.03162277660168379, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=3.308766276013816, gamma=0.03162277660168379, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END C=3.308766276013816, gamma=0.03162277660168379, kernel=linear;, score=0.878 total time=   0.0s
# [CV 1/5] END C=5.092375435231468, gamma=auto, kernel=poly;, score=0.930 total time=   0.0s
# [CV 2/5] END C=5.092375435231468, gamma=auto, kernel=poly;, score=0.911 total time=   0.0s
# [CV 3/5] END C=5.092375435231468, gamma=auto, kernel=poly;, score=0.911 total time=   0.0s
# [CV 4/5] END C=5.092375435231468, gamma=auto, kernel=poly;, score=0.885 total time=   0.0s
# [CV 5/5] END C=5.092375435231468, gamma=auto, kernel=poly;, score=0.897 total time=   0.0s
# [CV 1/5] END C=1.5473382371769873, gamma=1.0, kernel=poly;, score=0.924 total time=   0.0s
# [CV 2/5] END C=1.5473382371769873, gamma=1.0, kernel=poly;, score=0.898 total time=   0.0s
# [CV 3/5] END C=1.5473382371769873, gamma=1.0, kernel=poly;, score=0.911 total time=   0.0s
# [CV 4/5] END C=1.5473382371769873, gamma=1.0, kernel=poly;, score=0.892 total time=   0.0s
# [CV 5/5] END C=1.5473382371769873, gamma=1.0, kernel=poly;, score=0.897 total time=   0.0s
# [CV 1/5] END C=0.5085740331996756, gamma=scale, kernel=linear;, score=0.911 total time=   0.0s
# [CV 2/5] END C=0.5085740331996756, gamma=scale, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/5] END C=0.5085740331996756, gamma=scale, kernel=linear;, score=0.898 total time=   0.0s
# [CV 4/5] END C=0.5085740331996756, gamma=scale, kernel=linear;, score=0.873 total time=   0.0s
# [CV 5/5] END C=0.5085740331996756, gamma=scale, kernel=linear;, score=0.878 total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=18,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000153EB5F4620>,
#                                         'gamma': ['scale', 'auto', 0.001,
#                                                   0.03162277660168379, 1.0,
#                                                   31.622776601683793, 1000.0],
#                                         'kernel': ['linear', 'rbf', 'poly']},
#                    verbose=3)

# %%
from sklearn.metrics import accuracy_score

# Get the best hyperparameters and model
best_params_rand = randomized_search.best_params_
best_model_rand = randomized_search.best_estimator_

# Evaluate the best model
y_pred_best_rand = best_model_rand.predict(x_test)
accuracy_best_rand = accuracy_score(y_test, y_pred_best_rand)

print(f"Best SVM Accuracy: {accuracy_best_rand:.2f}")
print(f"Best Hyperparameters: {best_params_rand}")
# Out:
# Best SVM Accuracy: 0.91
# Best Hyperparameters: {'C': 2.695563349892356, 'gamma': 'scale', 'kernel': 'rbf'}
